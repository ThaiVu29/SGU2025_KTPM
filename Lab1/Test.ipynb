# %%
# %%writefile baie_t2.inp
# 0 0 0
# Out:
# Overwriting baie_t2.inp

# %%
# %%writefile baie_t1.inp
# 0 0 2
# Out:
# Overwriting baie_t1.inp

# %%
# %%writefile baie_t3.inp
# 0 2 8 # tuyến tính theo y
# Out:
# Overwriting baie_t3.inp

# %%
# %%writefile baie_t4.inp
# 1 0 1 # delta < 0
# Out:
# Overwriting baie_t4.inp

# %%
# %%writefile baie_t5.inp
# 1 4 4 # delta = 0
# Out:
# Overwriting baie_t5.inp

# %%
# %%writefile baie_t6.inp
# 1 -4 4 # delta = 0, y = 2
# Out:
# Writing baie_t6.inp

# %%
#====== COMPILE ======
# !g++ -std=c++17 -O2 -Wall baie1.cpp -o baie.exe

# ====== TEST 1 ======
# !baie.exe < baie_t1.inp > out1.txt
# !echo Expected: "Vô Nghiệm"
# !type out1.txt


# ====== TEST 2 ======
# !baie.exe < baie_t2.inp > out2.txt
# !echo Expected: "Vô số nghiệm"
# !type out2.txt

# ====== TEST 3 ======
# !baie.exe < baie_t3.inp > out3.txt
# !echo Expected: "Vô nghiệm, tuyến tính theo y, y =-4 <0"
# !type out3.txt
# ====== TEST 2=4 ======
# !baie.exe < baie_t4.inp > out4.txt
# !echo Expected: "Vô nghiệm, Delta < 0"
# !type out4.txt
# ====== TEST 5 ======
# !baie.exe < baie_t5.inp > out5.txt
# !echo Expected: "Vô nghiệm, Delta = 0 ,y <0"
# !type out5.txt
# ====== TEST 6 ======
# !baie.exe < baie_t6.inp > out6.txt
# !echo Expected: "{ +- (√2, √2)}, Δ=0, y=2"
# !type out6.txt
# Out:
# Expected: "V� Nghi?m"
# No solution.
# Expected: "V� s? nghi?m"
#  Infinite solutions.
# Expected: "V� nghi?m, tuy?n t�nh theo y, y =-4 <0"
# No solution.
# Expected: "V� nghi?m, Delta < 0"
# No solution.
# Expected: "V� nghi?m, Delta = 0 ,y <0"
# No solution.
# Expected: "{ +- (�2, �2)}, �=0, y=2"
#  The equation has 2 real solution(s): 1.41421 -1.41421
